# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# from textblob import TextBlob
import pandas as pd
from tabulate import tabulate

# %%
df = pd.read_csv("./data/synthetic.csv")
# sentences = df["User Input")
sentences = df["User Input"].tolist()

# %%
# df = pd.read_csv("./data/synthetic.csv")

# # # sentences = df['User Input']
# sentences = [
#     "I am feeling mildly sad today",
#     "I am feeling sad today",
#     "I am feeling very sad today",
#     "I am feeling  depressed today",
#     "I am feeling very depressed today",
#     "I am feeling little bit sad today",
#     "I am feeling very happy today",
#     "I am feeling the happiest today",
#     "I am feeling very angry today",
#     "I want to kill someone",
#     "I am so depressed I want to kill myself",
#     "I'm constantly worried about everything.",
#     "I’m trying, but I’m still feeling very anxious.",
#     "I feel hopeful sometimes and sometimes im lonely and confused",
#     "I am feeling hurt and depression",
#     "Im so sad",
#     "It\'s getting worse, I’ve been extremely stressed.",
#     "Im so overjoyed that I can't contain my excitement",
#     "I can\'t sleep well",
#     "I lie awake at night worrying and unable to sleep",
# # ]

# # sentences = [
#     "I am feeling a bit okay today.",                        # Level 1 - Mildly positive
#     "I am feeling a little uplifted today.",                 # Level 2
#     "I am feeling slightly pleased today.",                  # Level 3
#     "I am feeling happy today.",                             # Level 4 - Neutral positive
#     "I am feeling pretty joyful today.",                     # Level 5
#     "I am feeling very cheerful today.",                     # Level 6
#     "I am feeling wonderfully excited today.",               # Level 7 - Strongly positive
#     "I am feeling extremely thrilled today.",                # Level 8
#     "I am feeling overjoyed and ecstatic today!",            # Level 9
#     "I am feeling unbelievably euphoric today!"              # Level 10 - Highest positivity
# ]

# %%
# # Initialize VADER sentiment analyzer
# analyzer = SentimentIntensityAnalyzer()

# # Create lists to store results
# data = []

# # Analyze each sentence
# for sentence in sentences:
#     # VADER analysis
#     vader_scores = analyzer.polarity_scores(sentence)
    
#     # TextBlob analysis
#     # textblob_score = TextBlob(sentence).sentiment.polarity

#     # Append results
#     data.append([
#         sentence,
#         # vader_scores['pos'],
#         # vader_scores['neu'],
#         # vader_scores['neg'],
#         vader_scores['compound'],
#         # textblob_score
#     ])

# # Convert to DataFrame
# df_vader = pd.DataFrame(data, columns=["Sentence",  "VADER_Compound"])

# # Display DataFrame in a formatted table
# print(tabulate(df_vader, headers="keys", tablefmt="fancy_grid", showindex=False))

# %%
def calculate_intensity(compound):
    if compound >= 0:
        if compound > 0.71:
            return 4
        elif compound > 0.4:
            return 3
        elif compound > 0.35:
            return 2
        else:
            return 1
    elif compound < 0:
        if compound > -0.2:
            return 1
        elif compound > -0.3:
            return 2
        elif compound > -0.4:
            return 3
        elif compound > -0.5:
            return 4
        else:
            return 5

# %%
# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Create lists to store results
data = []

# Analyze each sentence
for sentence in sentences:
    # VADER analysis
    vader_scores = analyzer.polarity_scores(sentence)
    
    # TextBlob analysis
    # textblob_score = TextBlob(sentence).sentiment.polarity

    # Append results
    data.append([
        sentence,
        # vader_scores['pos'],
        # vader_scores['neu'],
        # vader_scores['neg'],
        calculate_intensity(vader_scores['compound']),
        # textblob_score
    ])

# Convert to DataFrame
df_vader = pd.DataFrame(data, columns=["Sentence",  "VADER_Compound"])

# Display DataFrame in a formatted table
print(tabulate(df_vader, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# ╒════════════════════════════════════════════════════════════════════════╤══════════════════╕
# │ Sentence                                                               │   VADER_Compound │
# ╞════════════════════════════════════════════════════════════════════════╪══════════════════╡
# │ I've been tossing and turning all night because I can't sleep well.    │                2 │
# ├────────────────────────────────────────────────────────────────────────┼──────────────────┤
# │ Work stress is making me unable to sleep properly.                     │                4 │
# ├────────────────────────────────────────────────────────────────────────┼──────────────────┤
# │ Since last month I have trouble sleeping and it's affecting my work.   │                4 │
# ├────────────────────────────────────────────────────────────────────────┼──────────────────┤
# │ My new medication is making me unable to sleep at night.               │                1 │
# ...

# %%
# Initialize counters
df["Intensity"] = pd.to_numeric(df["Intensity"], errors="coerce")
df_vader["VADER_Compound"] = pd.to_numeric(df_vader["VADER_Compound"], errors="coerce")
correct = 0
total = len(df)

# Loop through each row to compare "Intensity" and "VADER_Compound" values
for i in range(total):
    if abs(df["Intensity"].iloc[i] - df_vader["VADER_Compound"].iloc[i]) == 0:
        correct += 1

# Display results
print(f"Number of matching intensities: {correct}")
print(f"Total number of rows: {total}")
print(f"Accuracy: {(correct / total) * 100:.2f}%")
# Out:
# Number of matching intensities: 102
# Total number of rows: 477
# Accuracy: 21.38%

# %%
df["VADER_Compound"] = df_vader["VADER_Compound"]

# Initialize counters
df["Intensity"] = pd.to_numeric(df["Intensity"], errors="coerce")
correct = 0
total = len(df)

# Loop through each row to compare "Intensity" and "VADER_Compound" values
for i in range(total):
    if abs(df["Intensity"].iloc[i] - df["VADER_Compound"].iloc[i]) <= 2:
        correct += 1

# Display results
print(f"Number of matching intensities: {correct}")
print(f"Total number of rows: {total}")
print(f"Accuracy: {(correct / total) * 100:.2f}%")

# Save the updated DataFrame to a new CSV file
df.to_csv("./data/new_synthetic.csv", index=False)
print("Updated DataFrame saved to new_synthetic.csv")
# Out:
# Number of matching intensities: 467
# Total number of rows: 477
# Accuracy: 97.90%
# Updated DataFrame saved to new_synthetic.csv
